# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy 
import math
import random
import operator
from PIL import Image

# %%
im = Image.open("../data/NIH3T3/img/dna-0.png")
list(im.getdata())
# Out:
# [37,
#  39,
#  38,
#  39,
#  38,
#  39,
#  40,
#  39,
#  42,
#  43,
#  44,
#  45,
#  45,
#  46,
#  44,
#  46,
#  46,
#  44,
#  42,
#  40,
#  39,
#  39,
#  38,
#  37,
#  36,
#  37,
#  38,
#  39,
#  38,
#  38,
#  41,
#  43,
#  45,
#  45,
#  45,
#  42,
#  40,
#  39,
#  38,
#  37,
#  38,
#  38,
#  36,
#  37,
#  37,
#  39,
#  39,
#  39,
#  40,
#  41,
#  39,
#  36,
#  37,
#  34,
#  33,
#  35,
#  35,
#  35,
#  35,
#  34,
#  33,
#  31,
#  31,
#  29,
#  27,
#  24,
#  25,
#  23,
#  23,
#  21,
#  22,
#  22,
#  22,
#  22,
#  21,
#  22,
#  22,
#  22,
#  22,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  22,
#  21,
#  21,
#  21,
#  20,
#  21,
#  21,
#  22,
#  21,
#  21,
#  22,
#  21,
#  21,
#  20,
#  21,
#  21,
#  21,
#  20,
#  21,
#  21,
#  21,
#  21,
#  21,
#  20,
#  21,
#  21,
#  20,
#  21,
#  22,
#  21,
#  20,
#  21,
#  21,
#  20,
#  21,
#  21,
#  20,
#  21,
#  21,
#  21,
#  20,
#  21,
#  20,
#  21,
#  21,
#  20,
#  20,
#  21,
#  20,
#  21,
#  20,
#  21,
# ...
