# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: <object object at 0x000001271C6485C0>
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy

# %% [markdown]
# Loading the data and showing the images with a colobar.

# %%
yeast = imread("../data/Yeast_Cells.jpg")
figure()
#imshow(yeast), colorbar()
yeast1 = yeast.reshape((-1,3))
imshow(yeast1)

# %%
nuclei = imread("../data/Cell_Nuclei.tif")
imshow(nuclei), colorbar()
# Out:
# (<matplotlib.image.AxesImage at 0x2390259ceb0>,
#  <matplotlib.colorbar.Colorbar at 0x239025cdd30>)

# %%
otsu0 = imread("../data/NIH3T3/img/dna-0.png")
figure()
imshow(otsu0, "gray"), colorbar()
print(numpy.array(otsu0))
# Out:
# [[0.14509805 0.15294118 0.14901961 ... 0.07843138 0.07843138 0.07450981]
#  [0.16078432 0.14901961 0.14901961 ... 0.07843138 0.08235294 0.08235294]
#  [0.14901961 0.14901961 0.15686275 ... 0.08235294 0.08235294 0.07843138]
#  ...
#  [0.08627451 0.08235294 0.08627451 ... 0.09411765 0.09019608 0.09019608]
#  [0.08627451 0.09019608 0.08627451 ... 0.09411765 0.09019608 0.09411765]
#  [0.08627451 0.08235294 0.08627451 ... 0.09411765 0.09411765 0.09019608]]

# %% [markdown]
# Creating histograms of the image intensity values.

# %%
hist(yeast.flatten())
# Out:
# (array([3011005.,  250119.,  268891.,  273978.,  157098.,  171456.,
#          100732.,   48412.,   23144.,   15165.]),
#  array([  0. ,  23.4,  46.8,  70.2,  93.6, 117. , 140.4, 163.8, 187.2,
#         210.6, 234. ]),
#  <BarContainer object of 10 artists>)

# %%
hist(nuclei.flatten())
# Out:
# (array([373314., 895395., 593622., 418979., 424982., 237500., 115792.,
#          47699.,  19544.,  18901.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
hist(otsu0.flatten())
# Out:
# (array([1.135604e+06, 7.496300e+04, 1.158660e+05, 3.345500e+04,
#         1.157400e+04, 3.324000e+03, 9.930000e+02, 4.010000e+02,
#         6.800000e+01, 8.000000e+00]),
#  array([0.07058824, 0.10078432, 0.1309804 , 0.16117647, 0.19137256,
#         0.22156863, 0.2517647 , 0.2819608 , 0.31215686, 0.34235296,
#         0.37254903], dtype=float32),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Intensity clipping: Reducing the intensity spectrum of the images.

# %%
T1 = 50
T2 = 100

# %%
figure(figsize = (15, 8))
imshow(yeast.clip(T1, T2))
colorbar()

# %%
figure(figsize = (15, 8))
imshow(nuclei.clip(T1, T2))
colorbar()

# %%
figure(figsize = (15, 8))
imshow(otsu0.clip(0.1, 0.35), "gray")
colorbar()
